# %%
import pandas as pd
from scipy.io import loadmat

data = loadmat('data/raw/water_dataset.mat')

X = data['X_tr']
y = data['Y_tr'].ravel()

df = pd.DataFrame(X)

df.head()
# Out:
#                                                  0    \
# 0  [[0.0011306042884990253, 0.8846153846153847, 0...
#
#                                                  1    \
# 0  [[0.0011306042884990253, 0.8846153846153847, 0...
#
#                                                  2    \
# 0  [[0.0011306042884990253, 0.8846153846153847, 0...
#
#                                                  3    \
# 0  [[0.0011306042884990253, 0.8846153846153847, 0...
#
#                                                  4    \
# 0  [[0.0011306042884990253, 0.8846153846153847, 0...
#
#                                                  5    \
# 0  [[0.0011306042884990253, 0.8846153846153847, 0...
#
#                                                  6    \
# 0  [[0.0011111111111111111, 0.8846153846153847, 0...
#
#                                                  7    \
# 0  [[0.0010916179337231969, 0.8717948717948718, 0...
#
#                                                  8    \
# ...
